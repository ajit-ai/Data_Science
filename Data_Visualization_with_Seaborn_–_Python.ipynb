# %% [markdown]
# <a href="https://colab.research.google.com/github/ajit-ai/DataScience/blob/main/Data_Visualization_with_Seaborn_%E2%80%93_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualization is the presentation of data in pictorial format. It is extremely important for Data Analysis, primarily because of the fantastic ecosystem of data-centric Python packages. And it helps to understand the data, however, complex it is, the significance of data by summarizing and presenting a huge amount of data in a simple and easy-to-understand format and helps communicate information clearly and effectively.

# %%
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns

# initialise data of lists.
data = {'Name':['Mohe', 'Karnal', 'Yrik', 'jack'],
        'Age':[30, 21, 29, 28]}
df = pd.DataFrame(data)

# plotting lineplot
# The original code is trying to access a column that does not exist
# Use the existing columns in the dataframe to plot instead.
sns.lineplot(x='Name', y='Age', data=df)
# Out:
# <Axes: xlabel='Name', ylabel='Age'>

# %%
import pandas as pd
import seaborn as sns

# initialise data of lists
data = {'Name':[ 'Mohe' , 'Karnal' , 'Yrik' , 'jack' ],
        'Age':[ 30 , 21 , 29 , 28 ]}
df = pd.DataFrame( data )

# Use the correct alias 'sns' to call the scatterplot function
# The 'Weight' column does not exist, use 'Age' instead.
sns.scatterplot(x='Age', y='Age', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Age'>
